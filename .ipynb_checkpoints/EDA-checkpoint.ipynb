# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %%
# !python sample.py 0.01
#The argument decides how much propotion of whole data you want in random sample
# Out:
# Pickle successfully created in datasets folder

# %%
df=pd.read_pickle("../dataset/sample-train.pkl")

# %%
df
# Out:
#                                                    TITLE  \
# 0      Buddy Products Task File Organizer Rack, 4 Poc...
# 1      Peugeot 250201 Esprit Casual Tasting Glasses, ...
# 2      Leviton 5266-C 15 Amp, 125 Volt, Industrial Gr...
# 3                    Samsung Optical EA-OVF1 View Finder
# 4      Brother Laminated Tape Black on Clear, 6mm (Tz...
# ...                                                  ...
# 28979  Pikkme Oppo A3s / Realme C1 Back Cover Case | ...
# 28980  UNFAKENOW Casual Sleeveless Floral Print Women...
# 28981  KHANKAN Black Cotton Rayon Knee Length Long 3/...
# 28982  Inktree® Designer Printed Armor Back Case Cove...
# 28983  ShopsGeniune in-Ear Headphones YS Earphones fo...
#
#                                              DESCRIPTION  \
# 0      Buddy Products is a family-owned, privately-he...
# 1      The Esprit CASUAL glass, with its laid-back ro...
# 2      Size Name:1-Pack Product Description Electrica...
# 3                    Samsung Optical EA-OVF1 View Finder
# 4      Perfect for labeling file folders and binders,...
# ...                                                  ...
# 28979  Pikkme Oppo A3s / Realme C1 Back cover is best...
# 28980  UNFAKENOW Casual Sleeveless Floral Print Women...
# 28981  Black woven Kurti, has a round neck with a sho...
# 28982  </b><b>Now, Customize your phone cases with In...
# 28983  The new is a dynamic, extremely lightweight in...
#
#                                            BULLET_POINTS         BRAND  \
# 0      [Save space on your desktop and in your filing...         Buddy
# 1      [Product Type: Mixed Drinkware Sets,Set of fou...       Peugeot
# 2      [Leviton 2-Pole Industrial Grade Male Plug, St...       Leviton
# 3      [Enjoy more realistic view of the subject and ...       Samsung
# 4      [Black on Clear,6mm,26.2 ft (8m) yield,Standar...       BROTHER
# ...                                                  ...           ...
# 28979  [Protection: Oppo A3s / Realme C1 Cover and Ca...        Pikkme
# 28980  [Fabric : Rayon,Work : Floral Print,Type : Cro...     UNFAKENOW
# 28981  [Fabric: Rayon(fine quality),Item Length: Knee...       KHANKAN
# 28982  [DESIGNER CASE : Beautiful design, elegant app...       InkTree
# 28983  [One-button universal remote with mic: Answer ...  ShopsGeniune
#
#        BROWSE_NODE_ID
# 0                  37
# 1                 146
# 2                 195
# 3                 269
# 4                 313
# ...               ...
# 28979            1045
# 28980            1194
# 28981            1251
# 28982            1045
# 28983             811
#
# [28984 rows x 5 columns]
